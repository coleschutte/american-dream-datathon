# %%
import pandas as pd

data_dict = pd.DataFrame({
    "dataset": ["gdp_clean", "gdp_clean", "gdp_clean"],
    "column": ["State", "Year", "GDP"],
    "description": [
        "U.S. state (including District of Columbia)",
        "Year of observation (integer)",
        "Gross Domestic Product in millions of current U.S. dollars"
    ]
})

data_dict.to_csv("../data/cleaned/data_dictionary.csv", index=False)

# %%
import pandas as pd

income_dict = pd.DataFrame({
    "dataset": ["income_pc_clean", "income_pc_clean", "income_pc_clean"],
    "column": ["State", "Year", "Income_pc"],
    "description": [
        "U.S. state or District of Columbia",
        "Year of observation (integer)",
        "Per capita personal income in current U.S. dollars"
    ]
})

income_dict.to_csv("../data/cleaned/data_dictionary.csv", mode="a", header=False, index=False)

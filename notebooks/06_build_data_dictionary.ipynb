# %%
import pandas as pd

data_dict = pd.DataFrame({
    "dataset": ["gdp_clean", "gdp_clean", "gdp_clean"],
    "column": ["State", "Year", "GDP"],
    "description": [
        "U.S. state (including District of Columbia)",
        "Year of observation (integer)",
        "Gross Domestic Product in millions of current U.S. dollars"
    ]
})

data_dict.to_csv("../data/metadata/data_dictionary.csv", index=False)

# %%
import pandas as pd

income_dict = pd.DataFrame({
    "dataset": ["income_pc_clean", "income_pc_clean", "income_pc_clean"],
    "column": ["State", "Year", "Income_pc"],
    "description": [
        "U.S. state or District of Columbia",
        "Year of observation (integer)",
        "Per capita personal income in current U.S. dollars"
    ]
})

income_dict.to_csv("../data/metadata/data_dictionary.csv", mode="a", header=False, index=False)

# %%
import pandas as pd

real_income_dict = pd.DataFrame({
    "dataset": ["real_income_pc_clean", "real_income_pc_clean", "real_income_pc_clean"],
    "column": ["State", "Year", "Real_Income_pc"],
    "description": [
        "U.S. state or District of Columbia",
        "Year of observation (integer)",
        "Real per capita personal income in constant 2017 U.S. dollars"
    ]
})

real_income_dict.to_csv("../data/metadata/data_dictionary.csv", mode="a", header=False, index=False)

# %%
import pandas as pd

real_income_dict = pd.DataFrame({
    "dataset": ["regional_price_parity_clean", "regional_price_parity_clean", "regional_price_parity_clean"],
    "column": ["State", "Year", "Regional_Price_Parity"],
    "description": [
        "U.S. state or District of Columbia",
        "Year of observation (integer)",
        "Index measuring the relative cost of living across U.S. states, where 100 represents the national average. Values above 100 indicate higher-than-average prices, and values below 100 indicate lower-than-average prices."
    ]
})

real_income_dict.to_csv("../data/metadata/data_dictionary.csv", mode="a", header=False, index=False)

# %%
import pandas as pd

employment_dict = pd.DataFrame({
    "dataset": ["employment_clean", "employment_clean", "employment_clean"],
    "column": ["State", "Year", "Employment"],
    "description": [
        "U.S. state or District of Columbia",
        "Year of observation (integer)",
        "Total employment representing the number of jobs in the state for the given year."
    ]
})

employment_dict.to_csv("../data/metadata/data_dictionary.csv", mode="a", header=False, index=False)
